# %% [markdown]
# HW2 Imge Display
# Name : 박채희
# Student Number: 201910803

# %%
import numpy as np
from scipy.misc.pilutil import imread,imresize
import matplotlib.pyplot as plt

img=imread('C:/Users/chaeh/faker.jpg')
img_tinted=img*[1,0.8,0.8]
plt.subplot(1,2,1)
plt.imshow(img)

plt.subplot(1,2,2)
plt.imshow(np.uint8(img_tinted))
plt.show()
# Out:
# C:\Users\chaeh\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   """
