# %%
import pyspark

# %%
myConf=pyspark.SparkConf()
spark=pyspark.sql.SparkSession.builder.master("local").appName("myApp").config(conf=myConf).getOrCreate()

# %% [markdown]
# # 10주차 과제

# %%
# %%writefile police.txt
# 존경하는 국민 여러분, 경찰관 여러분, 일흔네 돌 ‘경찰의 날’입니다.
#
# 국민의 안전을 위해 밤낮없이 애쓰시는 전국의 15만 경찰관 여러분께 먼저 감사를 드립니다. 전몰·순직 경찰관들의 고귀한 희생에 경의를 표합니다. 유가족 여러분께 위로의 마음을 전합니다.
#
# 오늘 홍조근정훈장을 받으신 중앙경찰학교장 이은정 치안감님, 근정포장을 받으신 광주남부경찰서 김동현 경감님을 비롯한 수상자 여러분께 각별한 축하와 감사를 드립니다. 또한 경찰 영웅으로 추서되신 차일혁, 최중락님께 국민의 사랑을 전해드립니다.
#
# 사랑하는 경찰관 여러분,
#
# 여러분의 헌신적 노력으로 우리의 치안은 참 좋아졌습니다. 지난해 범죄 발생은 2015년에 비해 15.1% 줄었습니다. 같은 기간 교통사고 사망자는 18.2% 감소했습니다.
#
# 치안의 개선은 국민의 체감으로 나타나고 있습니다. 올해 상반기 국민의 체감안전도는 74.5점으로 역대 최고를 기록했습니다. 범죄안전도는 처음으로 80점을 넘었습니다.
#
# 한국을 찾는 외국 관광객들도 우리의 치안을 가장 좋게 평가합니다. 한국의 무엇이 좋았느냐는 물음에 외국 관광객들은 7년 연속으로 치안이 가장 좋았다고 응답했습니다. 개발도상국들은 우리의 경찰을 모범으로 삼으려 합니다.
#
# 올해는 ‘경찰의 날’에 맞춰 국제치안산업박람회와 서울국제경찰청장회의가 함께 열립니다. 우리의 치안 발전과 치안산업 발전이 세계에 더 널리 알려지게 될 것입니다.
#
# 자랑스러운 경찰관 여러분,
#
# 경찰헌장은 “나라와 겨레를 위하여 충성”을 다한다는 다짐으로 시작합니다. 헌장처럼 우리 경찰은 ‘나라와 겨레를 위한 충성’의 길을 걸으려 노력해 왔습니다.
#
# 대한민국 경찰은 1945년 광복 직후에 공식 탄생했습니다. 그러나 그 뿌리는 대한민국 임시정부에 닿아 있습니다.
#
# 임시정부 초대 경무국장 백범 김구 선생과 나석주, 나창헌, 유상근 의사 등 임시정부 경찰은 앞장서서 일제와 싸웠습니다. 일본 관헌에게 폭탄을 던지고, 밀정을 응징하며, 임정 요인들을 보호했습니다.
#
# 광복 이후 6·25전쟁에서도 경찰은 국군과 함께 피를 흘렸습니다. 그 전쟁에서 1만여 명의 경찰관이 목숨을 잃었습니다. 그 후로도 경찰은 국민의 안전을 지키고 국가의 안보를 도왔습니다. 역대 경찰의 헌신에 대해 국민과 함께 거듭 감사의 말씀을 드립니다. 감사합니다.
#
# 그러나 잘못도 없지는 않았습니다. 한때 경찰은 공권력을 무리하게 집행하며 국민의 인권을 훼손했습니다. 부실하거나 불공정한 수사로 국민의 지탄을 받은 적도 있습니다. 무기력한 법 집행으로 국민께 걱정을 드리기도 했습니다.
#
# 지금 경찰은 과거를 돌아보며 국민과 국가에 충성하는 경찰로 거듭나려고 노력하고 있습니다. 경찰은 문재인 정부 들어 가장 먼저 개혁위원회를 만들고 자체개혁에 나섰습니다. 경찰의 개혁을 국민은 큰 기대로 주목하고 있습니다.
#
# 검경 수사권 조정과 자치경찰제 도입이 국회에서 논의되고 있습니다. 국회가 조속히 입법을 매듭지어 주시기 바랍니다. 그리하여 경찰이 중립성, 공정성, 전문성을 갖추고 본연의 임무를 충실히 수행하는 선진경찰로 더욱 발전해 주기를 소망합니다.
#
# 정부는 경찰의 근무여건을 개선하기 위해 노력하고 있습니다. 이미 경찰관 8,572명을 늘렸고, 앞으로도 충원을 계속할 것입니다. 특히 일선 경찰의 근무환경을 개선하겠습니다.
#
# 정부는 누구도 법 위에 군림하지 못하는 법치주의를 확립하고자 합니다. 그러자면 검찰과 경찰이 법을 누구에게나 엄정하고 공정하게 집행해야 됩니다. 수사 또한 엄정하고 공정해야 합니다. 동시에 검찰과 경찰 스스로도 법을 엄격히 준수해야 합니다. 특히 공권력이 인권의 제약을 수반하는 경우에는 절제하며 행사하는 것이 마땅합니다. 검찰개혁과 경찰개혁은 더 미룰 수 없는 시대적 과제가 됐습니다.
#
# 경찰헌장은 따뜻한 경찰, 의로운 경찰, 공정한 경찰을 다짐합니다. 흔들림 없이 그 길로 가시기 바랍니다. 국민이 여러분을 응원할 것입니다.
#
# 행사를 준비하신 민갑룡 경찰청장님과 관계자 여러분, 고맙습니다. 함께하신 진영 행정안전부 장관님, 이용범 인천시의회 의장님, 박정훈 경찰위원장님, 강영규 경우회장님과 역대 경찰청장님, 그리고 우리 시민 경찰님들을 비롯한 내빈 여러분, 고맙습니다.
#
# 감사합니다.
# Out:
# Writing police.txt

# %%
police = spark\
    .read\
    .options(header='false', inferschema='true', delimiter='\t')\
    .csv("police.txt")\
    .withColumnRenamed("_c0", "sentence")

# %%
police.show()
# Out:
# +----------------------------------+
# |                          sentence|
# +----------------------------------+
# |  존경하는 국민 여러분, 경찰관 ...|
# | 국민의 안전을 위해 밤낮없이 애...|
# |오늘 홍조근정훈장을 받으신 중앙...|
# |           사랑하는 경찰관 여러분,|
# |여러분의 헌신적 노력으로 우리의...|
# | 치안의 개선은 국민의 체감으로 ...|
# | 한국을 찾는 외국 관광객들도 우...|
# |   올해는 ‘경찰의 날’에 맞춰 국...|
# |         자랑스러운 경찰관 여러분,|
# | 경찰헌장은 “나라와 겨레를 위하...|
# |    대한민국 경찰은 1945년 광복...|
# | 임시정부 초대 경무국장 백범 김...|
# |    광복 이후 6·25전쟁에서도 경...|
# |그러나 잘못도 없지는 않았습니다...|
# | 지금 경찰은 과거를 돌아보며 국...|
# | 검경 수사권 조정과 자치경찰제 ...|
# |정부는 경찰의 근무여건을 개선하...|
# | 정부는 누구도 법 위에 군림하지...|
# | 경찰헌장은 따뜻한 경찰, 의로운...|
# |행사를 준비하신 민갑룡 경찰청장...|
# +----------------------------------+
# only showing top 20 rows

# %%
police.count()
# Out:
# 21

# %%
from pyspark.ml.feature import Tokenizer
tokenizer = Tokenizer(inputCol="sentence", outputCol="tokens")
tokDf = tokenizer.transform(police) #단어로 분리

# %%
tokDf.show()
# Out:
# +----------------------------------+--------------------------------+
# |                          sentence|                          tokens|
# +----------------------------------+--------------------------------+
# |  존경하는 국민 여러분, 경찰관 ...|   [존경하는, 국민, 여러분,, ...|
# | 국민의 안전을 위해 밤낮없이 애...|  [국민의, 안전을, 위해, 밤낮...|
# |오늘 홍조근정훈장을 받으신 중앙...|[오늘, 홍조근정훈장을, 받으신...|
# |           사랑하는 경찰관 여러분,|     [사랑하는, 경찰관, 여러분,]|
# |여러분의 헌신적 노력으로 우리의...| [여러분의, 헌신적, 노력으로,...|
# | 치안의 개선은 국민의 체감으로 ...|  [치안의, 개선은, 국민의, 체...|
# | 한국을 찾는 외국 관광객들도 우...|  [한국을, 찾는, 외국, 관광객...|
# |   올해는 ‘경찰의 날’에 맞춰 국...|    [올해는, ‘경찰의, 날’에, ...|
# |         자랑스러운 경찰관 여러분,|   [자랑스러운, 경찰관, 여러분,]|
# | 경찰헌장은 “나라와 겨레를 위하...| [경찰헌장은, “나라와, 겨레를...|
# |    대한민국 경찰은 1945년 광복...|    [대한민국, 경찰은, 1945년...|
# | 임시정부 초대 경무국장 백범 김...|  [임시정부, 초대, 경무국장, ...|
# |    광복 이후 6·25전쟁에서도 경...|    [광복, 이후, 6·25전쟁에서...|
# |그러나 잘못도 없지는 않았습니다...|  [그러나, 잘못도, 없지는, 않...|
# | 지금 경찰은 과거를 돌아보며 국...|  [지금, 경찰은, 과거를, 돌아...|
# | 검경 수사권 조정과 자치경찰제 ...|  [검경, 수사권, 조정과, 자치...|
# |정부는 경찰의 근무여건을 개선하...| [정부는, 경찰의, 근무여건을,...|
# | 정부는 누구도 법 위에 군림하지...|   [정부는, 누구도, 법, 위에,...|
# | 경찰헌장은 따뜻한 경찰, 의로운...|  [경찰헌장은, 따뜻한, 경찰,,...|
# |행사를 준비하신 민갑룡 경찰청장...|  [행사를, 준비하신, 민갑룡, ...|
# +----------------------------------+--------------------------------+
# only showing top 20 rows

# %%
wordList=['존경하는', '국민', '여러분,', '경찰관', '여러분,', '일흔네', '‘경찰의', '날’입니다.']

# %%
cleaned=list()
for w in wordList:
    cleaned.append(w.lstrip('‘').rstrip("’").rstrip(',').rstrip('.').replace("’","").replace("”",""))
cleaned
# Out:
# ['존경하는', '국민', '여러분', '경찰관', '여러분', '일흔네', '경찰의', '날입니다']

# %%
import re

#udf 함수 : 컴마,따옴표, 마침표, 숫자 제거

def trim(wordList):
    regex = re.compile('\d+')
    cleaned=list()
    for w in wordList:
        if not regex.match(w):
            cleaned.append(w.lstrip('‘').rstrip("’").rstrip(',').rstrip('.').replace("’","").replace("”",""))
    return cleaned

# %%
from pyspark.sql import functions as f
from pyspark.sql.types import ArrayType, StringType

trimUdf=f.udf(trim, ArrayType(StringType()))

# %%
wordsDf = tokDf.withColumn('words', trimUdf(f.col('tokens')))

# %%
wordsDf.show()
# Out:
# +----------------------------------+--------------------------------+--------------------------------+
# |                          sentence|                          tokens|                           words|
# +----------------------------------+--------------------------------+--------------------------------+
# |  존경하는 국민 여러분, 경찰관 ...|   [존경하는, 국민, 여러분,, ...|  [존경하는, 국민, 여러분, 경...|
# | 국민의 안전을 위해 밤낮없이 애...|  [국민의, 안전을, 위해, 밤낮...|  [국민의, 안전을, 위해, 밤낮...|
# |오늘 홍조근정훈장을 받으신 중앙...|[오늘, 홍조근정훈장을, 받으신...|[오늘, 홍조근정훈장을, 받으신...|
# |           사랑하는 경찰관 여러분,|     [사랑하는, 경찰관, 여러분,]|      [사랑하는, 경찰관, 여러분]|
# |여러분의 헌신적 노력으로 우리의...| [여러분의, 헌신적, 노력으로,...| [여러분의, 헌신적, 노력으로,...|
# | 치안의 개선은 국민의 체감으로 ...|  [치안의, 개선은, 국민의, 체...|  [치안의, 개선은, 국민의, 체...|
# | 한국을 찾는 외국 관광객들도 우...|  [한국을, 찾는, 외국, 관광객...|  [한국을, 찾는, 외국, 관광객...|
# |   올해는 ‘경찰의 날’에 맞춰 국...|    [올해는, ‘경찰의, 날’에, ...|  [올해는, 경찰의, 날에, 맞춰...|
# |         자랑스러운 경찰관 여러분,|   [자랑스러운, 경찰관, 여러분,]|    [자랑스러운, 경찰관, 여러분]|
# | 경찰헌장은 “나라와 겨레를 위하...| [경찰헌장은, “나라와, 겨레를...| [경찰헌장은, “나라와, 겨레를...|
# |    대한민국 경찰은 1945년 광복...|    [대한민국, 경찰은, 1945년...|  [대한민국, 경찰은, 광복, 직...|
# | 임시정부 초대 경무국장 백범 김...|  [임시정부, 초대, 경무국장, ...|  [임시정부, 초대, 경무국장, ...|
# |    광복 이후 6·25전쟁에서도 경...|    [광복, 이후, 6·25전쟁에서...|  [광복, 이후, 경찰은, 국군과...|
# |그러나 잘못도 없지는 않았습니다...|  [그러나, 잘못도, 없지는, 않...|  [그러나, 잘못도, 없지는, 않...|
# | 지금 경찰은 과거를 돌아보며 국...|  [지금, 경찰은, 과거를, 돌아...|  [지금, 경찰은, 과거를, 돌아...|
# | 검경 수사권 조정과 자치경찰제 ...|  [검경, 수사권, 조정과, 자치...|  [검경, 수사권, 조정과, 자치...|
# |정부는 경찰의 근무여건을 개선하...| [정부는, 경찰의, 근무여건을,...| [정부는, 경찰의, 근무여건을,...|
# | 정부는 누구도 법 위에 군림하지...|   [정부는, 누구도, 법, 위에,...|   [정부는, 누구도, 법, 위에,...|
# | 경찰헌장은 따뜻한 경찰, 의로운...|  [경찰헌장은, 따뜻한, 경찰,,...|  [경찰헌장은, 따뜻한, 경찰, ...|
# |행사를 준비하신 민갑룡 경찰청장...|  [행사를, 준비하신, 민갑룡, ...|  [행사를, 준비하신, 민갑룡, ...|
# +----------------------------------+--------------------------------+--------------------------------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import StopWordsRemover
stop = StopWordsRemover(inputCol="words", outputCol="nostops")

_mystopwords=[u"참",u"큰", u"돌",u"더",u"그",u"될",u"등"]
stop.setStopWords(_mystopwords)
# Out:
# StopWordsRemover_e48d31f23abd

# %%
stopDf=stop.transform(wordsDf) #불용어 제거 된 컬럼
stopDf.show()
# Out:
# +----------------------------------+--------------------------------+--------------------------------+--------------------------------+
# |                          sentence|                          tokens|                           words|                         nostops|
# +----------------------------------+--------------------------------+--------------------------------+--------------------------------+
# |  존경하는 국민 여러분, 경찰관 ...|   [존경하는, 국민, 여러분,, ...|  [존경하는, 국민, 여러분, 경...|  [존경하는, 국민, 여러분, 경...|
# | 국민의 안전을 위해 밤낮없이 애...|  [국민의, 안전을, 위해, 밤낮...|  [국민의, 안전을, 위해, 밤낮...|  [국민의, 안전을, 위해, 밤낮...|
# |오늘 홍조근정훈장을 받으신 중앙...|[오늘, 홍조근정훈장을, 받으신...|[오늘, 홍조근정훈장을, 받으신...|[오늘, 홍조근정훈장을, 받으신...|
# |           사랑하는 경찰관 여러분,|     [사랑하는, 경찰관, 여러분,]|      [사랑하는, 경찰관, 여러분]|      [사랑하는, 경찰관, 여러분]|
# |여러분의 헌신적 노력으로 우리의...| [여러분의, 헌신적, 노력으로,...| [여러분의, 헌신적, 노력으로,...| [여러분의, 헌신적, 노력으로,...|
# | 치안의 개선은 국민의 체감으로 ...|  [치안의, 개선은, 국민의, 체...|  [치안의, 개선은, 국민의, 체...|  [치안의, 개선은, 국민의, 체...|
# | 한국을 찾는 외국 관광객들도 우...|  [한국을, 찾는, 외국, 관광객...|  [한국을, 찾는, 외국, 관광객...|  [한국을, 찾는, 외국, 관광객...|
# |   올해는 ‘경찰의 날’에 맞춰 국...|    [올해는, ‘경찰의, 날’에, ...|  [올해는, 경찰의, 날에, 맞춰...|  [올해는, 경찰의, 날에, 맞춰...|
# |         자랑스러운 경찰관 여러분,|   [자랑스러운, 경찰관, 여러분,]|    [자랑스러운, 경찰관, 여러분]|    [자랑스러운, 경찰관, 여러분]|
# | 경찰헌장은 “나라와 겨레를 위하...| [경찰헌장은, “나라와, 겨레를...| [경찰헌장은, “나라와, 겨레를...| [경찰헌장은, “나라와, 겨레를...|
# |    대한민국 경찰은 1945년 광복...|    [대한민국, 경찰은, 1945년...|  [대한민국, 경찰은, 광복, 직...|  [대한민국, 경찰은, 광복, 직...|
# | 임시정부 초대 경무국장 백범 김...|  [임시정부, 초대, 경무국장, ...|  [임시정부, 초대, 경무국장, ...|  [임시정부, 초대, 경무국장, ...|
# |    광복 이후 6·25전쟁에서도 경...|    [광복, 이후, 6·25전쟁에서...|  [광복, 이후, 경찰은, 국군과...|  [광복, 이후, 경찰은, 국군과...|
# |그러나 잘못도 없지는 않았습니다...|  [그러나, 잘못도, 없지는, 않...|  [그러나, 잘못도, 없지는, 않...|  [그러나, 잘못도, 없지는, 않...|
# | 지금 경찰은 과거를 돌아보며 국...|  [지금, 경찰은, 과거를, 돌아...|  [지금, 경찰은, 과거를, 돌아...|  [지금, 경찰은, 과거를, 돌아...|
# | 검경 수사권 조정과 자치경찰제 ...|  [검경, 수사권, 조정과, 자치...|  [검경, 수사권, 조정과, 자치...|  [검경, 수사권, 조정과, 자치...|
# |정부는 경찰의 근무여건을 개선하...| [정부는, 경찰의, 근무여건을,...| [정부는, 경찰의, 근무여건을,...| [정부는, 경찰의, 근무여건을,...|
# | 정부는 누구도 법 위에 군림하지...|   [정부는, 누구도, 법, 위에,...|   [정부는, 누구도, 법, 위에,...|   [정부는, 누구도, 법, 위에,...|
# | 경찰헌장은 따뜻한 경찰, 의로운...|  [경찰헌장은, 따뜻한, 경찰,,...|  [경찰헌장은, 따뜻한, 경찰, ...|  [경찰헌장은, 따뜻한, 경찰, ...|
# |행사를 준비하신 민갑룡 경찰청장...|  [행사를, 준비하신, 민갑룡, ...|  [행사를, 준비하신, 민갑룡, ...|  [행사를, 준비하신, 민갑룡, ...|
# +----------------------------------+--------------------------------+--------------------------------+--------------------------------+
# only showing top 20 rows

# %%
# 비교용
stopDf.select('words').show(1,truncate=False)
stopDf.select('nostops').show(1,truncate=False)
# Out:
# +----------------------------------------------------------------------+
# |words                                                                 |
# +----------------------------------------------------------------------+
# |[존경하는, 국민, 여러분, 경찰관, 여러분, 일흔네, 돌, 경찰의, 날입니다]|
# +----------------------------------------------------------------------+
# only showing top 1 row
#
# +------------------------------------------------------------------+
# |nostops                                                           |
# +------------------------------------------------------------------+
# |[존경하는, 국민, 여러분, 경찰관, 여러분, 일흔네, 경찰의, 날입니다]|
# +------------------------------------------------------------------+
# only showing top 1 row

# %%
from pyspark.ml.feature import HashingTF, IDF

hashTF = HashingTF(inputCol="nostops", outputCol="hash")
hashDf = hashTF.transform(stopDf)

# %%
hashDf.show()
# Out:
# +----------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------+
# |                          sentence|                          tokens|                           words|                         nostops|                hash|
# +----------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------+
# |  존경하는 국민 여러분, 경찰관 ...|   [존경하는, 국민, 여러분,, ...|  [존경하는, 국민, 여러분, 경...|  [존경하는, 국민, 여러분, 경...|(262144,[162,6225...|
# | 국민의 안전을 위해 밤낮없이 애...|  [국민의, 안전을, 위해, 밤낮...|  [국민의, 안전을, 위해, 밤낮...|  [국민의, 안전을, 위해, 밤낮...|(262144,[5341,307...|
# |오늘 홍조근정훈장을 받으신 중앙...|[오늘, 홍조근정훈장을, 받으신...|[오늘, 홍조근정훈장을, 받으신...|[오늘, 홍조근정훈장을, 받으신...|(262144,[29823,32...|
# |           사랑하는 경찰관 여러분,|     [사랑하는, 경찰관, 여러분,]|      [사랑하는, 경찰관, 여러분]|      [사랑하는, 경찰관, 여러분]|(262144,[89874,16...|
# |여러분의 헌신적 노력으로 우리의...| [여러분의, 헌신적, 노력으로,...| [여러분의, 헌신적, 노력으로,...| [여러분의, 헌신적, 노력으로,...|(262144,[3407,726...|
# | 치안의 개선은 국민의 체감으로 ...|  [치안의, 개선은, 국민의, 체...|  [치안의, 개선은, 국민의, 체...|  [치안의, 개선은, 국민의, 체...|(262144,[9986,233...|
# | 한국을 찾는 외국 관광객들도 우...|  [한국을, 찾는, 외국, 관광객...|  [한국을, 찾는, 외국, 관광객...|  [한국을, 찾는, 외국, 관광객...|(262144,[7183,239...|
# |   올해는 ‘경찰의 날’에 맞춰 국...|    [올해는, ‘경찰의, 날’에, ...|  [올해는, 경찰의, 날에, 맞춰...|  [올해는, 경찰의, 날에, 맞춰...|(262144,[554,4988...|
# |         자랑스러운 경찰관 여러분,|   [자랑스러운, 경찰관, 여러분,]|    [자랑스러운, 경찰관, 여러분]|    [자랑스러운, 경찰관, 여러분]|(262144,[89874,16...|
# | 경찰헌장은 “나라와 겨레를 위하...| [경찰헌장은, “나라와, 겨레를...| [경찰헌장은, “나라와, 겨레를...| [경찰헌장은, “나라와, 겨레를...|(262144,[4628,206...|
# |    대한민국 경찰은 1945년 광복...|    [대한민국, 경찰은, 1945년...|  [대한민국, 경찰은, 광복, 직...|  [대한민국, 경찰은, 광복, 직...|(262144,[32368,34...|
# | 임시정부 초대 경무국장 백범 김...|  [임시정부, 초대, 경무국장, ...|  [임시정부, 초대, 경무국장, ...|  [임시정부, 초대, 경무국장, ...|(262144,[17472,23...|
# |    광복 이후 6·25전쟁에서도 경...|    [광복, 이후, 6·25전쟁에서...|  [광복, 이후, 경찰은, 국군과...|  [광복, 이후, 경찰은, 국군과...|(262144,[7101,105...|
# |그러나 잘못도 없지는 않았습니다...|  [그러나, 잘못도, 없지는, 않...|  [그러나, 잘못도, 없지는, 않...|  [그러나, 잘못도, 없지는, 않...|(262144,[20328,20...|
# | 지금 경찰은 과거를 돌아보며 국...|  [지금, 경찰은, 과거를, 돌아...|  [지금, 경찰은, 과거를, 돌아...|  [지금, 경찰은, 과거를, 돌아...|(262144,[4505,391...|
# | 검경 수사권 조정과 자치경찰제 ...|  [검경, 수사권, 조정과, 자치...|  [검경, 수사권, 조정과, 자치...|  [검경, 수사권, 조정과, 자치...|(262144,[7731,187...|
# |정부는 경찰의 근무여건을 개선하...| [정부는, 경찰의, 근무여건을,...| [정부는, 경찰의, 근무여건을,...| [정부는, 경찰의, 근무여건을,...|(262144,[8701,243...|
# | 정부는 누구도 법 위에 군림하지...|   [정부는, 누구도, 법, 위에,...|   [정부는, 누구도, 법, 위에,...|   [정부는, 누구도, 법, 위에,...|(262144,[6358,113...|
# | 경찰헌장은 따뜻한 경찰, 의로운...|  [경찰헌장은, 따뜻한, 경찰,,...|  [경찰헌장은, 따뜻한, 경찰, ...|  [경찰헌장은, 따뜻한, 경찰, ...|(262144,[3401,206...|
# |행사를 준비하신 민갑룡 경찰청장...|  [행사를, 준비하신, 민갑룡, ...|  [행사를, 준비하신, 민갑룡, ...|  [행사를, 준비하신, 민갑룡, ...|(262144,[4007,402...|
# +----------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------+
# only showing top 20 rows

# %%
idf = IDF(inputCol="hash", outputCol="idf")

idfModel = idf.fit(hashDf)
idfDf = idfModel.transform(hashDf)

# %%
idfDf.show()
# Out:
# +----------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------+--------------------+
# |                          sentence|                          tokens|                           words|                         nostops|                hash|                 idf|
# +----------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------+--------------------+
# |  존경하는 국민 여러분, 경찰관 ...|   [존경하는, 국민, 여러분,, ...|  [존경하는, 국민, 여러분, 경...|  [존경하는, 국민, 여러분, 경...|(262144,[162,6225...|(262144,[162,6225...|
# | 국민의 안전을 위해 밤낮없이 애...|  [국민의, 안전을, 위해, 밤낮...|  [국민의, 안전을, 위해, 밤낮...|  [국민의, 안전을, 위해, 밤낮...|(262144,[5341,307...|(262144,[5341,307...|
# |오늘 홍조근정훈장을 받으신 중앙...|[오늘, 홍조근정훈장을, 받으신...|[오늘, 홍조근정훈장을, 받으신...|[오늘, 홍조근정훈장을, 받으신...|(262144,[29823,32...|(262144,[29823,32...|
# |           사랑하는 경찰관 여러분,|     [사랑하는, 경찰관, 여러분,]|      [사랑하는, 경찰관, 여러분]|      [사랑하는, 경찰관, 여러분]|(262144,[89874,16...|(262144,[89874,16...|
# |여러분의 헌신적 노력으로 우리의...| [여러분의, 헌신적, 노력으로,...| [여러분의, 헌신적, 노력으로,...| [여러분의, 헌신적, 노력으로,...|(262144,[3407,726...|(262144,[3407,726...|
# | 치안의 개선은 국민의 체감으로 ...|  [치안의, 개선은, 국민의, 체...|  [치안의, 개선은, 국민의, 체...|  [치안의, 개선은, 국민의, 체...|(262144,[9986,233...|(262144,[9986,233...|
# | 한국을 찾는 외국 관광객들도 우...|  [한국을, 찾는, 외국, 관광객...|  [한국을, 찾는, 외국, 관광객...|  [한국을, 찾는, 외국, 관광객...|(262144,[7183,239...|(262144,[7183,239...|
# |   올해는 ‘경찰의 날’에 맞춰 국...|    [올해는, ‘경찰의, 날’에, ...|  [올해는, 경찰의, 날에, 맞춰...|  [올해는, 경찰의, 날에, 맞춰...|(262144,[554,4988...|(262144,[554,4988...|
# |         자랑스러운 경찰관 여러분,|   [자랑스러운, 경찰관, 여러분,]|    [자랑스러운, 경찰관, 여러분]|    [자랑스러운, 경찰관, 여러분]|(262144,[89874,16...|(262144,[89874,16...|
# | 경찰헌장은 “나라와 겨레를 위하...| [경찰헌장은, “나라와, 겨레를...| [경찰헌장은, “나라와, 겨레를...| [경찰헌장은, “나라와, 겨레를...|(262144,[4628,206...|(262144,[4628,206...|
# |    대한민국 경찰은 1945년 광복...|    [대한민국, 경찰은, 1945년...|  [대한민국, 경찰은, 광복, 직...|  [대한민국, 경찰은, 광복, 직...|(262144,[32368,34...|(262144,[32368,34...|
# | 임시정부 초대 경무국장 백범 김...|  [임시정부, 초대, 경무국장, ...|  [임시정부, 초대, 경무국장, ...|  [임시정부, 초대, 경무국장, ...|(262144,[17472,23...|(262144,[17472,23...|
# |    광복 이후 6·25전쟁에서도 경...|    [광복, 이후, 6·25전쟁에서...|  [광복, 이후, 경찰은, 국군과...|  [광복, 이후, 경찰은, 국군과...|(262144,[7101,105...|(262144,[7101,105...|
# |그러나 잘못도 없지는 않았습니다...|  [그러나, 잘못도, 없지는, 않...|  [그러나, 잘못도, 없지는, 않...|  [그러나, 잘못도, 없지는, 않...|(262144,[20328,20...|(262144,[20328,20...|
# | 지금 경찰은 과거를 돌아보며 국...|  [지금, 경찰은, 과거를, 돌아...|  [지금, 경찰은, 과거를, 돌아...|  [지금, 경찰은, 과거를, 돌아...|(262144,[4505,391...|(262144,[4505,391...|
# | 검경 수사권 조정과 자치경찰제 ...|  [검경, 수사권, 조정과, 자치...|  [검경, 수사권, 조정과, 자치...|  [검경, 수사권, 조정과, 자치...|(262144,[7731,187...|(262144,[7731,187...|
# |정부는 경찰의 근무여건을 개선하...| [정부는, 경찰의, 근무여건을,...| [정부는, 경찰의, 근무여건을,...| [정부는, 경찰의, 근무여건을,...|(262144,[8701,243...|(262144,[8701,243...|
# | 정부는 누구도 법 위에 군림하지...|   [정부는, 누구도, 법, 위에,...|   [정부는, 누구도, 법, 위에,...|   [정부는, 누구도, 법, 위에,...|(262144,[6358,113...|(262144,[6358,113...|
# | 경찰헌장은 따뜻한 경찰, 의로운...|  [경찰헌장은, 따뜻한, 경찰,,...|  [경찰헌장은, 따뜻한, 경찰, ...|  [경찰헌장은, 따뜻한, 경찰, ...|(262144,[3401,206...|(262144,[3401,206...|
# |행사를 준비하신 민갑룡 경찰청장...|  [행사를, 준비하신, 민갑룡, ...|  [행사를, 준비하신, 민갑룡, ...|  [행사를, 준비하신, 민갑룡, ...|(262144,[4007,402...|(262144,[4007,402...|
# +----------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
for e in idfDf.select("hash","idf").take(5):
    print(e)
# Out:
# Row(hash=SparseVector(262144, {162: 1.0, 62257: 1.0, 80697: 1.0, 80732: 1.0, 89874: 2.0, 127225: 1.0, 160086: 1.0}), idf=SparseVector(262144, {162: 2.3979, 62257: 2.3979, 80697: 1.2993, 80732: 2.3979, 89874: 2.9632, 127225: 2.3979, 160086: 1.2993}))
# Row(hash=SparseVector(262144, {5341: 1.0, 30732: 1.0, 43098: 1.0, 49855: 1.0, 63600: 1.0, 75300: 1.0, 77757: 1.0, 89318: 1.0, 96799: 1.0, 123553: 1.0, 138372: 1.0, 160081: 1.0, 160086: 1.0, 167255: 1.0, 178931: 1.0, 208192: 1.0, 217323: 2.0, 224666: 1.0, 247023: 1.0, 257249: 1.0, 261393: 1.0}), idf=SparseVector(262144, {5341: 2.3979, 30732: 2.3979, 43098: 2.3979, 49855: 1.9924, 63600: 2.3979, 75300: 2.3979, 77757: 1.9924, 89318: 1.9924, 96799: 2.3979, 123553: 1.9924, 138372: 1.7047, 160081: 2.3979, 160086: 1.2993, 167255: 1.2993, 178931: 2.3979, 208192: 2.3979, 217323: 3.9849, 224666: 2.3979, 247023: 2.3979, 257249: 2.3979, 261393: 2.3979}))
# Row(hash=SparseVector(262144, {29823: 1.0, 32228: 1.0, 36822: 1.0, 49855: 1.0, 61014: 1.0, 61103: 1.0, 72971: 1.0, 82902: 1.0, 84159: 1.0, 89227: 1.0, 91126: 1.0, 118725: 2.0, 138372: 1.0, 153204: 1.0, 167255: 1.0, 169211: 1.0, 185989: 1.0, 206065: 1.0, 217323: 1.0, 220284: 1.0, 235673: 1.0, 237148: 1.0, 248593: 1.0, 249689: 1.0, 251574: 1.0, 254458: 1.0}), idf=SparseVector(262144, {29823: 2.3979, 32228: 2.3979, 36822: 2.3979, 49855: 1.9924, 61014: 2.3979, 61103: 2.3979, 72971: 2.3979, 82902: 1.9924, 84159: 1.9924, 89227: 2.3979, 91126: 2.3979, 118725: 4.7958, 138372: 1.7047, 153204: 2.3979, 167255: 1.2993, 169211: 2.3979, 185989: 2.3979, 206065: 2.3979, 217323: 1.9924, 220284: 2.3979, 235673: 2.3979, 237148: 2.3979, 248593: 2.3979, 249689: 2.3979, 251574: 1.7047, 254458: 2.3979}))
# Row(hash=SparseVector(262144, {89874: 1.0, 160086: 1.0, 220702: 1.0}), idf=SparseVector(262144, {89874: 1.4816, 160086: 1.2993, 220702: 2.3979}))
# Row(hash=SparseVector(262144, {3407: 1.0, 7262: 1.0, 11202: 1.0, 28414: 1.0, 53633: 1.0, 63981: 1.0, 92349: 1.0, 93327: 1.0, 108997: 1.0, 110381: 1.0, 112697: 1.0, 121827: 1.0, 199006: 1.0, 211370: 1.0, 251648: 1.0, 256489: 1.0}), idf=SparseVector(262144, {3407: 2.3979, 7262: 2.3979, 11202: 2.3979, 28414: 2.3979, 53633: 2.3979, 63981: 2.3979, 92349: 2.3979, 93327: 2.3979, 108997: 2.3979, 110381: 2.3979, 112697: 2.3979, 121827: 2.3979, 199006: 2.3979, 211370: 2.3979, 251648: 2.3979, 256489: 1.7047}))

# %%
from pyspark.ml.feature import Word2Vec

word2Vec = Word2Vec(vectorSize=20, minCount=1, inputCol="tokens", outputCol="w2v")
model = word2Vec.fit(tokDf)
w2vDf = model.transform(tokDf)

# %%
w2vDf.show()
# Out:
# +----------------------------------+--------------------------------+--------------------+
# |                          sentence|                          tokens|                 w2v|
# +----------------------------------+--------------------------------+--------------------+
# |  존경하는 국민 여러분, 경찰관 ...|   [존경하는, 국민, 여러분,, ...|[-7.0726378665616...|
# | 국민의 안전을 위해 밤낮없이 애...|  [국민의, 안전을, 위해, 밤낮...|[-0.0047952424755...|
# |오늘 홍조근정훈장을 받으신 중앙...|[오늘, 홍조근정훈장을, 받으신...|[2.44510042075826...|
# |           사랑하는 경찰관 여러분,|     [사랑하는, 경찰관, 여러분,]|[-0.0096088195374...|
# |여러분의 헌신적 노력으로 우리의...| [여러분의, 헌신적, 노력으로,...|[0.00139344426570...|
# | 치안의 개선은 국민의 체감으로 ...|  [치안의, 개선은, 국민의, 체...|[6.09525055753895...|
# | 한국을 찾는 외국 관광객들도 우...|  [한국을, 찾는, 외국, 관광객...|[0.00259099903956...|
# |   올해는 ‘경찰의 날’에 맞춰 국...|    [올해는, ‘경찰의, 날’에, ...|[-6.6505488326871...|
# |         자랑스러운 경찰관 여러분,|   [자랑스러운, 경찰관, 여러분,]|[-0.0028656715682...|
# | 경찰헌장은 “나라와 겨레를 위하...| [경찰헌장은, “나라와, 겨레를...|[3.33765763666872...|
# |    대한민국 경찰은 1945년 광복...|    [대한민국, 경찰은, 1945년...|[0.00335763817773...|
# | 임시정부 초대 경무국장 백범 김...|  [임시정부, 초대, 경무국장, ...|[-0.0041974790306...|
# |    광복 이후 6·25전쟁에서도 경...|    [광복, 이후, 6·25전쟁에서...|[-4.9824296812792...|
# |그러나 잘못도 없지는 않았습니다...|  [그러나, 잘못도, 없지는, 않...|[0.00521271912320...|
# | 지금 경찰은 과거를 돌아보며 국...|  [지금, 경찰은, 과거를, 돌아...|[-7.3701596452987...|
# | 검경 수사권 조정과 자치경찰제 ...|  [검경, 수사권, 조정과, 자치...|[2.16520857065916...|
# |정부는 경찰의 근무여건을 개선하...| [정부는, 경찰의, 근무여건을,...|[-0.0022236386663...|
# | 정부는 누구도 법 위에 군림하지...|   [정부는, 누구도, 법, 위에,...|[-1.3553726545069...|
# | 경찰헌장은 따뜻한 경찰, 의로운...|  [경찰헌장은, 따뜻한, 경찰,,...|[0.00479411092884...|
# |행사를 준비하신 민갑룡 경찰청장...|  [행사를, 준비하신, 민갑룡, ...|[-0.0017017016237...|
# +----------------------------------+--------------------------------+--------------------+
# only showing top 20 rows

# %%
model.getVectors().show()
# Out:
# +-----------+--------------------+
# |       word|              vector|
# +-----------+--------------------+
# |   공정해야|[0.01903676055371...|
# | 자치경찰제|[0.01591804251074...|
# |   공권력을|[-0.0078636398538...|
# |흘렸습니다.|[-0.0064704646356...|
# |     만들고|[-0.0129344444721...|
# |     헌신에|[0.00207491824403...|
# |    나창헌,|[0.00645125051960...|
# |       닿아|[-0.0164423175156...|
# |         돌|[-8.8439020328223...|
# |     민갑룡|[-0.0021277430932...|
# |     수상자|[0.00567383645102...|
# |       기간|[0.02045899257063...|
# |     시대적|[0.00745315616950...|
# |     일흔네|[-0.0057396423071...|
# |  했습니다.|[0.02299980632960...|
# |       범죄|[-0.0215433388948...|
# |  됐습니다.|[0.01477840170264...|
# |       검경|[-0.0097690308466...|
# |   공권력이|[-0.0136569915339...|
# |     치안이|[-0.0194787681102...|
# +-----------+--------------------+
# only showing top 20 rows

# %%
model.findSynonyms("공권력이", 5).show()
# Out:
# +-----------+------------------+
# |       word|        similarity|
# +-----------+------------------+
# |     경찰관| 0.571321427822113|
# |       닿아|0.5587061643600464|
# |         수|0.5510228276252747|
# |흘렸습니다.|0.5261813402175903|
# |잃었습니다.|0.4806522727012634|
# +-----------+------------------+

# %% [markdown]
# # 11주차 과제

# %%
def normDist(x1, x2):
    dist = np.linalg.norm(x1 - x2)
    return dist

# %%
def cluster(x, k, centroids):
    row, col = x.shape
    clusterAssigned = np.zeros(shape=(row, 2), dtype=float)
    # print (clusterAssigned)
    clusterUpdated=True
    iter = 1
    while(clusterUpdated):
        print ("\n\n====== Iteration {} ======".format(iter))
        # STEP 1: assign to closer cluster
        for i in range(row):
            minDist = np.inf   # set arbitray max to minDist
            minIndex = -1      # set arbitray index to minIndex
            # compute distance and assign to closer cluster
            for j in range(k):
                # distance from centroids[j] to x[0]
                distJI = normDist(centroids[j], x[i])
                # print ("Distance {:.3f} between {} and {}".format(distJI, centroids[j], x[i]))
                # pick the closest centroid
                if distJI < minDist:
                    minDist = distJI
                    minIndex = j
            print (".....Assigning {} to {}th centroid by {:.3f}".format(x[i], minIndex, minDist))
            clusterAssigned[i] = [minIndex, minDist]   #-----changed
        print ("\n.....Assigned clusters: \n {}".format(clusterAssigned))
        # STEP 2: update centroids
        _centroids=np.zeros(shape = (k, x.shape[1]), dtype=float)
        for cent in range(k):
            # read data by index and average them
            _centroids[cent] = np.mean(x[clusterAssigned[:,0]==cent],axis=0)
        # print ("Centroids updated: \n", _centroids)
        # STEP 3: see if centroids is updated. STOP if NOT updated
        comparison = np.equal(centroids, _centroids) # np.isclose() in case some tolerence is required
        if(comparison.all() == True):
            print ("\n.....NOT Updating Centroids\n {} => \n{}".format(centroids, _centroids))
            clusterUpdated = False
            return centroids, clusterAssigned
        else:
            print ("\n.....Updating Centroids\n {} => \n{}".format(centroids, _centroids))
            centroids = _centroids
            iter += 1

# %%
def draw(x, centroids):
    import matplotlib.pyplot as plt
    #plt.subplot(5,2,iter)
    plt.scatter(x[:,0], x[:,1], color='blue')
    plt.scatter(centroids[:,0], centroids[:,1], color='red')

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=100, centers=4, cluster_std=0.60, random_state=0)

# %%
y
# Out:
# array([0, 3, 0, 0, 0, 0, 2, 3, 0, 3, 3, 3, 3, 3, 3, 1, 1, 2, 2, 1, 0, 3,
#        2, 1, 0, 2, 2, 0, 1, 1, 1, 3, 1, 1, 2, 0, 3, 1, 3, 2, 0, 2, 3, 2,
#        2, 3, 1, 2, 0, 0, 0, 1, 2, 2, 2, 3, 3, 1, 1, 3, 3, 1, 1, 0, 1, 3,
#        2, 2, 1, 0, 3, 1, 0, 3, 0, 0, 2, 2, 1, 1, 1, 3, 2, 0, 1, 2, 1, 1,
#        0, 0, 0, 2, 0, 2, 2, 3, 3, 2, 3, 0])

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

k = 4
centroids = np.array([[-3,3], [-3,8], [2,4], [2,1]], dtype = float)
centroids, clusterAssigned = cluster(X, k, centroids)
draw(X, centroids)
# Out:
# ====== Iteration 1 ======
# .....Assigning [0.669787   3.59540802] to 2th centroid by 1.390
# .....Assigning [-2.02396992  7.99569054] to 1th centroid by 0.976
# .....Assigning [1.43289271 4.37679234] to 2th centroid by 0.681
# .....Assigning [1.06923853 4.53068484] to 2th centroid by 1.071
# .....Assigning [1.71444449 5.02521524] to 2th centroid by 1.064
# .....Assigning [0.74387399 4.12240568] to 2th centroid by 1.262
# .....Assigning [-2.04363942  4.06392123] to 0th centroid by 1.431
# .....Assigning [-0.67860329  7.88799076] to 1th centroid by 2.324
# .....Assigning [-0.04749204  5.47425256] to 2th centroid by 2.523
# .....Assigning [-1.46976488  7.69183251] to 1th centroid by 1.561
# .....Assigning [-0.86417686  6.86528639] to 1th centroid by 2.419
# .....Assigning [-1.84838498  6.90859736] to 1th centroid by 1.587
# .....Assigning [-1.27182547  7.13460392] to 1th centroid by 1.933
# .....Assigning [-0.93428978  7.73253222] to 1th centroid by 2.083
# .....Assigning [-0.73415741  7.44484466] to 1th centroid by 2.333
# .....Assigning [3.18515794 0.08900822] to 3th centroid by 1.495
# .....Assigning [1.35139348 2.06383637] to 3th centroid by 1.246
# .....Assigning [-0.09701715  3.48456995] to 2th centroid by 2.159
# .....Assigning [-1.93150361  2.9369806 ] to 0th centroid by 1.070
# .....Assigning [2.73890793 0.15676817] to 3th centroid by 1.121
# .....Assigning [2.33812285 3.43116792] to 2th centroid by 0.662
# .....Assigning [-1.93673697  7.57276799] to 1th centroid by 1.146
# .....Assigning [-1.98885366  3.24143178] to 0th centroid by 1.040
# .....Assigning [ 2.33466499 -0.02408255] to 3th centroid by 1.077
# .....Assigning [0.43899014 4.53592883] to 2th centroid by 1.650
# .....Assigning [-1.58597553  2.51979529] to 0th centroid by 1.493
# .....Assigning [-0.3731388   3.80619114] to 2th centroid by 2.381
# .....Assigning [0.76752279 4.39759671] to 2th centroid by 1.295
# .....Assigning [2.94821884 2.03519717] to 3th centroid by 1.404
# .....Assigning [2.76253526 0.78970876] to 3th centroid by 0.791
# .....Assigning [1.65179125 0.68193176] to 3th centroid by 0.472
# .....Assigning [-0.8731169   6.87422542] to 1th centroid by 2.406
# .....Assigning [2.16172321 0.6565951 ] to 3th centroid by 0.380
# .....Assigning [2.06156753 1.96918596] to 3th centroid by 0.971
# .....Assigning [-1.15845639  3.47120626] to 0th centroid by 1.901
# .....Assigning [1.1641107  3.79132988] to 2th centroid by 0.862
# .....Assigning [-1.54707525  8.99317925] to 1th centroid by 1.760
# .....Assigning [1.81336135 1.6311307 ] to 3th centroid by 0.658
# .....Assigning [0.04968579 8.63737679] to 1th centroid by 3.116
# .....Assigning [-1.97375691  2.42201914] to 0th centroid by 1.178
# .....Assigning [1.06269622 5.17635143] to 2th centroid by 1.504
# .....Assigning [-1.42689992  3.29890112] to 0th centroid by 1.601
# .....Assigning [-1.63442682  6.50141812] to 1th centroid by 2.027
# .....Assigning [-2.07459735  3.58809203] to 0th centroid by 1.096
# .....Assigning [-1.94364473  2.82810154] to 0th centroid by 1.070
# .....Assigning [-1.98351709  8.3420778 ] to 1th centroid by 1.072
# .....Assigning [1.53278923 0.55035386] to 3th centroid by 0.648
# .....Assigning [-1.90841166  3.32374224] to 0th centroid by 1.139
# .....Assigning [0.67047877 4.04094275] to 2th centroid by 1.330
# .....Assigning [0.44359863 3.11530945] to 2th centroid by 1.790
# .....Assigning [0.22459286 4.77028154] to 2th centroid by 1.935
# .....Assigning [1.868336   0.93136287] to 3th centroid by 0.148
# .....Assigning [-1.18094952  2.79290301] to 0th centroid by 1.831
# .....Assigning [-1.78799614  4.0274405 ] to 0th centroid by 1.589
# .....Assigning [-0.85092246  2.26992336] to 0th centroid by 2.270
# .....Assigning [-1.26285145  7.39264147] to 1th centroid by 1.840
# .....Assigning [-0.78518144  8.32956251] to 1th centroid by 2.239
# .....Assigning [2.49272186 0.97505341] to 3th centroid by 0.493
# .....Assigning [2.26908736 1.32160756] to 3th centroid by 0.419
# .....Assigning [-0.5354379   8.02562558] to 1th centroid by 2.465
# .....Assigning [-1.46065212  7.01048924] to 1th centroid by 1.830
# .....Assigning [1.41281595 1.5303347 ] to 3th centroid by 0.791
# .....Assigning [2.13141478 1.13885728] to 3th centroid by 0.191
# .....Assigning [1.89593761 5.18540259] to 2th centroid by 1.190
# .....Assigning [1.29297652 1.47930168] to 3th centroid by 0.854
# .....Assigning [-0.58846002  8.22861825] to 1th centroid by 2.422
# .....Assigning [-2.31644846  2.6409315 ] to 0th centroid by 0.772
# .....Assigning [-1.28929999  2.26204536] to 0th centroid by 1.863
# .....Assigning [2.18023251 1.48364708] to 3th centroid by 0.516
# .....Assigning [1.24258802 4.50399192] to 2th centroid by 0.910
# .....Assigning [-1.86880148  8.24441673] to 1th centroid by 1.157
# .....Assigning [1.35617762 1.43815955] to 3th centroid by 0.779
# .....Assigning [0.91433877 4.55014643] to 2th centroid by 1.217
# .....Assigning [-1.52157528  7.84594751] to 1th centroid by 1.486
# .....Assigning [1.00372519 4.19147702] to 2th centroid by 1.015
# .....Assigning [1.4949318  3.85848832] to 2th centroid by 0.525
# .....Assigning [-0.40636864  3.46150906] to 2th centroid by 2.466
# .....Assigning [-1.68770604  3.3993561 ] to 0th centroid by 1.372
# .....Assigning [2.29667251 0.48677761] to 3th centroid by 0.593
# .....Assigning [1.07714851 1.17533301] to 3th centroid by 0.939
# .....Assigning [ 1.56737975 -0.1381059 ] to 3th centroid by 1.218
# .....Assigning [-1.69199357  8.76126877] to 1th centroid by 1.513
# .....Assigning [-1.34796111  3.7137138 ] to 0th centroid by 1.800
# .....Assigning [0.00793137 4.17614316] to 2th centroid by 2.000
# .....Assigning [1.67467427 0.68001896] to 3th centroid by 0.456
# .....Assigning [-0.95855283  2.82487621] to 0th centroid by 2.049
# .....Assigning [1.5108885 0.9288309] to 3th centroid by 0.494
# .....Assigning [1.80709613 0.44919077] to 3th centroid by 0.584
# .....Assigning [1.87271752 4.18069237] to 2th centroid by 0.221
# .....Assigning [1.01618041 4.48527047] to 2th centroid by 1.097
# .....Assigning [0.95936074 4.56078645] to 2th centroid by 1.182
# .....Assigning [-1.30104869  2.25824179] to 0th centroid by 1.854
# .....Assigning [0.3471383  3.45177657] to 2th centroid by 1.741
# .....Assigning [-1.12352716  3.16235936] to 0th centroid by 1.883
# .....Assigning [-2.42165857  3.18151728] to 0th centroid by 0.606
# .....Assigning [-1.91088578  7.86675906] to 1th centroid by 1.097
# .....Assigning [-1.73030157  7.42173015] to 1th centroid by 1.395
# .....Assigning [-1.56784898  3.94588789] to 0th centroid by 1.716
# .....Assigning [-0.69574048  8.02669661] to 1th centroid by 2.304
# .....Assigning [-0.55552381  4.69595848] to 2th centroid by 2.649
#
# .....Assigned clusters:
#  [[2.         1.39038171]
#  [1.         0.97603959]
#  [2.         0.6808694 ]
#  [2.         1.07142116]
#  [2.         1.06424068]
#  [2.         1.26207595]
#  [0.         1.43057818]
#  [1.         2.32409741]
#  [2.         2.52302284]
#  [1.         1.56095699]
#  [1.         2.41853581]
#  [1.         1.58662436]
#  [1.         1.93274354]
#  [1.         2.08295409]
#  [1.         2.33286093]
#  [3.         1.4948262 ]
#  [3.         1.2459688 ]
#  [2.         2.15943258]
#  [0.         1.0703532 ]
#  [3.         1.1211712 ]
#  [2.         0.66173786]
#  [1.         1.14588633]
#  [0.         1.03957021]
#  [3.         1.0773791 ]
#  [2.         1.65044584]
#  [0.         1.49333913]
#  [2.         2.38103961]
#  [2.         1.29502248]
#  [3.         1.4038348 ]
#  [3.         0.79100091]
#  [3.         0.47161079]
#  [1.         2.40644969]
#  [3.         0.37958046]
#  [3.         0.97113953]
#  [0.         1.90087301]
#  [2.         0.86154172]
#  [1.         1.75994186]
#  [3.         0.65814888]
#  [1.         3.11557902]
#  [0.         1.17781016]
#  [2.         1.50410806]
#  [0.         1.60124506]
#  [1.         2.02744612]
#  [0.         1.09645899]
#  [0.         1.07025022]
#  [1.         1.07249929]
#  [3.         0.64843469]
#  [0.         1.13858427]
#  [2.         1.3301515 ]
#  [2.         1.79026886]
#  [2.         1.93530467]
#  [3.         0.14848052]
#  [0.         1.83080141]
#  [0.         1.588895  ]
#  [0.         2.26970178]
#  [1.         1.84026342]
#  [1.         2.23920358]
#  [3.         0.49335298]
#  [3.         0.41933212]
#  [1.         2.46469532]
#  [1.         1.82995176]
#  [3.         0.7912269 ]
#  [3.         0.19118365]
#  [2.         1.18996146]
#  [3.         0.85417346]
#  [1.         2.42235245]
#  [0.         0.77212233]
#  [0.         1.86308121]
#  [3.         0.51613783]
#  [2.         0.90976962]
#  [1.         1.15730274]
#  [3.         0.77877536]
#  [2.         1.21709548]
#  [1.         1.48642922]
#  [2.         1.01450823]
#  [2.         0.5245183 ]
#  [2.         2.46588372]
#  [0.         1.37171453]
#  [3.         0.59279997]
#  [3.         0.93935964]
#  [3.         1.21755711]
#  [1.         1.51341037]
#  [0.         1.79961659]
#  [2.         1.99984095]
#  [3.         0.45631645]
#  [0.         2.04894482]
#  [3.         0.49426218]
#  [3.         0.58361178]
#  [2.         0.22102163]
#  [2.         1.09699061]
#  [2.         1.18212161]
#  [0.         1.85381789]
#  [2.         1.74140769]
#  [0.         1.88348371]
#  [0.         0.60615785]
#  [1.         1.09723422]
#  [1.         1.39518103]
#  [0.         1.71632178]
#  [1.         2.30441416]
#  [2.         2.64859588]]
#
# .....Updating Centroids
#  [[-3.  3.]
#  [-3.  8.]
#  [ 2.  4.]
#  [ 2.  1.]] =>
# [[-1.63043905  3.09879034]
#  [-1.27208964  7.74944718]
#  [ 0.78627354  4.2491454 ]
#  [ 1.97918933  0.97920012]]
#
#
# ====== Iteration 2 ======
# .....Assigning [0.669787   3.59540802] to 2th centroid by 0.664
# .....Assigning [-2.02396992  7.99569054] to 1th centroid by 0.791
# .....Assigning [1.43289271 4.37679234] to 2th centroid by 0.659
# .....Assigning [1.06923853 4.53068484] to 2th centroid by 0.399
# .....Assigning [1.71444449 5.02521524] to 2th centroid by 1.210
# .....Assigning [0.74387399 4.12240568] to 2th centroid by 0.134
# .....Assigning [-2.04363942  4.06392123] to 0th centroid by 1.050
# .....Assigning [-0.67860329  7.88799076] to 1th centroid by 0.609
# .....Assigning [-0.04749204  5.47425256] to 2th centroid by 1.482
# .....Assigning [-1.46976488  7.69183251] to 1th centroid by 0.206
# .....Assigning [-0.86417686  6.86528639] to 1th centroid by 0.974
# .....Assigning [-1.84838498  6.90859736] to 1th centroid by 1.019
# .....Assigning [-1.27182547  7.13460392] to 1th centroid by 0.615
# .....Assigning [-0.93428978  7.73253222] to 1th centroid by 0.338
# .....Assigning [-0.73415741  7.44484466] to 1th centroid by 0.618
# .....Assigning [3.18515794 0.08900822] to 3th centroid by 1.499
# .....Assigning [1.35139348 2.06383637] to 3th centroid by 1.253
# .....Assigning [-0.09701715  3.48456995] to 2th centroid by 1.168
# .....Assigning [-1.93150361  2.9369806 ] to 0th centroid by 0.342
# .....Assigning [2.73890793 0.15676817] to 3th centroid by 1.120
# .....Assigning [2.33812285 3.43116792] to 2th centroid by 1.754
# .....Assigning [-1.93673697  7.57276799] to 1th centroid by 0.688
# .....Assigning [-1.98885366  3.24143178] to 0th centroid by 0.386
# .....Assigning [ 2.33466499 -0.02408255] to 3th centroid by 1.064
# .....Assigning [0.43899014 4.53592883] to 2th centroid by 0.450
# .....Assigning [-1.58597553  2.51979529] to 0th centroid by 0.581
# .....Assigning [-0.3731388   3.80619114] to 2th centroid by 1.241
# .....Assigning [0.76752279 4.39759671] to 2th centroid by 0.150
# .....Assigning [2.94821884 2.03519717] to 3th centroid by 1.433
# .....Assigning [2.76253526 0.78970876] to 3th centroid by 0.806
# .....Assigning [1.65179125 0.68193176] to 3th centroid by 0.442
# .....Assigning [-0.8731169   6.87422542] to 1th centroid by 0.962
# .....Assigning [2.16172321 0.6565951 ] to 3th centroid by 0.371
# .....Assigning [2.06156753 1.96918596] to 3th centroid by 0.993
# .....Assigning [-1.15845639  3.47120626] to 0th centroid by 0.601
# .....Assigning [1.1641107  3.79132988] to 2th centroid by 0.594
# .....Assigning [-1.54707525  8.99317925] to 1th centroid by 1.274
# .....Assigning [1.81336135 1.6311307 ] to 3th centroid by 0.673
# .....Assigning [0.04968579 8.63737679] to 1th centroid by 1.592
# .....Assigning [-1.97375691  2.42201914] to 0th centroid by 0.759
# .....Assigning [1.06269622 5.17635143] to 2th centroid by 0.968
# .....Assigning [-1.42689992  3.29890112] to 0th centroid by 0.285
# .....Assigning [-1.63442682  6.50141812] to 1th centroid by 1.300
# .....Assigning [-2.07459735  3.58809203] to 0th centroid by 0.661
# .....Assigning [-1.94364473  2.82810154] to 0th centroid by 0.414
# .....Assigning [-1.98351709  8.3420778 ] to 1th centroid by 0.926
# .....Assigning [1.53278923 0.55035386] to 3th centroid by 0.619
# .....Assigning [-1.90841166  3.32374224] to 0th centroid by 0.358
# .....Assigning [0.67047877 4.04094275] to 2th centroid by 0.238
# .....Assigning [0.44359863 3.11530945] to 2th centroid by 1.184
# .....Assigning [0.22459286 4.77028154] to 2th centroid by 0.766
# .....Assigning [1.868336   0.93136287] to 3th centroid by 0.121
# .....Assigning [-1.18094952  2.79290301] to 0th centroid by 0.544
# .....Assigning [-1.78799614  4.0274405 ] to 0th centroid by 0.942
# .....Assigning [-0.85092246  2.26992336] to 0th centroid by 1.138
# .....Assigning [-1.26285145  7.39264147] to 1th centroid by 0.357
# .....Assigning [-0.78518144  8.32956251] to 1th centroid by 0.757
# .....Assigning [2.49272186 0.97505341] to 3th centroid by 0.514
# .....Assigning [2.26908736 1.32160756] to 3th centroid by 0.449
# .....Assigning [-0.5354379   8.02562558] to 1th centroid by 0.787
# .....Assigning [-1.46065212  7.01048924] to 1th centroid by 0.763
# .....Assigning [1.41281595 1.5303347 ] to 3th centroid by 0.790
# .....Assigning [2.13141478 1.13885728] to 3th centroid by 0.221
# .....Assigning [1.89593761 5.18540259] to 2th centroid by 1.452
# .....Assigning [1.29297652 1.47930168] to 3th centroid by 0.849
# .....Assigning [-0.58846002  8.22861825] to 1th centroid by 0.835
# .....Assigning [-2.31644846  2.6409315 ] to 0th centroid by 0.825
# .....Assigning [-1.28929999  2.26204536] to 0th centroid by 0.904
# .....Assigning [2.18023251 1.48364708] to 3th centroid by 0.543
# .....Assigning [1.24258802 4.50399192] to 2th centroid by 0.523
# .....Assigning [-1.86880148  8.24441673] to 1th centroid by 0.775
# .....Assigning [1.35617762 1.43815955] to 3th centroid by 0.774
# .....Assigning [0.91433877 4.55014643] to 2th centroid by 0.327
# .....Assigning [-1.52157528  7.84594751] to 1th centroid by 0.267
# .....Assigning [1.00372519 4.19147702] to 2th centroid by 0.225
# .....Assigning [1.4949318  3.85848832] to 2th centroid by 0.809
# .....Assigning [-0.40636864  3.46150906] to 0th centroid by 1.277
# .....Assigning [-1.68770604  3.3993561 ] to 0th centroid by 0.306
# .....Assigning [2.29667251 0.48677761] to 3th centroid by 0.586
# .....Assigning [1.07714851 1.17533301] to 3th centroid by 0.923
# .....Assigning [ 1.56737975 -0.1381059 ] to 3th centroid by 1.191
# .....Assigning [-1.69199357  8.76126877] to 1th centroid by 1.095
# .....Assigning [-1.34796111  3.7137138 ] to 0th centroid by 0.677
# .....Assigning [0.00793137 4.17614316] to 2th centroid by 0.782
# .....Assigning [1.67467427 0.68001896] to 3th centroid by 0.427
# .....Assigning [-0.95855283  2.82487621] to 0th centroid by 0.726
# .....Assigning [1.5108885 0.9288309] to 3th centroid by 0.471
# .....Assigning [1.80709613 0.44919077] to 3th centroid by 0.557
# .....Assigning [1.87271752 4.18069237] to 2th centroid by 1.089
# .....Assigning [1.01618041 4.48527047] to 2th centroid by 0.330
# .....Assigning [0.95936074 4.56078645] to 2th centroid by 0.356
# .....Assigning [-1.30104869  2.25824179] to 0th centroid by 0.903
# .....Assigning [0.3471383  3.45177657] to 2th centroid by 0.910
# .....Assigning [-1.12352716  3.16235936] to 0th centroid by 0.511
# .....Assigning [-2.42165857  3.18151728] to 0th centroid by 0.796
# .....Assigning [-1.91088578  7.86675906] to 1th centroid by 0.649
# .....Assigning [-1.73030157  7.42173015] to 1th centroid by 0.563
# .....Assigning [-1.56784898  3.94588789] to 0th centroid by 0.849
# .....Assigning [-0.69574048  8.02669661] to 1th centroid by 0.640
# .....Assigning [-0.55552381  4.69595848] to 2th centroid by 1.414
#
# .....Assigned clusters:
#  [[2.         0.66403439]
#  [1.         0.79117618]
#  [2.         0.65909795]
#  [2.         0.39916619]
#  [2.         1.20987012]
#  [2.         0.13364385]
#  [0.         1.04986294]
#  [1.         0.60944267]
#  [2.         1.48190843]
#  [1.         0.20590034]
#  [1.         0.97372129]
#  [1.         1.0193845 ]
#  [1.         0.61484332]
#  [1.         0.33822309]
#  [1.         0.61818588]
#  [3.         1.49893359]
#  [3.         1.25322122]
#  [2.         1.16823715]
#  [0.         0.34179272]
#  [3.         1.11962791]
#  [2.         1.75423016]
#  [1.         0.68772932]
#  [0.         0.3857559 ]
#  [3.         1.0643961 ]
#  [2.         0.45038927]
#  [0.         0.58069981]
#  [2.         1.24114682]
#  [2.         0.14963082]
#  [3.         1.4332299 ]
#  [3.         0.8059391 ]
#  [3.         0.44221938]
#  [1.         0.96186921]
#  [3.         0.3706651 ]
#  [3.         0.99340733]
#  [0.         0.60121648]
#  [2.         0.59359579]
#  [1.         1.27376863]
#  [3.         0.67269042]
#  [1.         1.59232825]
#  [0.         0.7588718 ]
#  [2.         0.96753322]
#  [0.         0.28543389]
#  [1.         1.2995633 ]
#  [0.         0.66082732]
#  [0.         0.41396887]
#  [1.         0.9259266 ]
#  [3.         0.61901709]
#  [0.         0.35759213]
#  [2.         0.2382368 ]
#  [2.         1.18448725]
#  [2.         0.76620367]
#  [3.         0.12073468]
#  [0.         0.54369835]
#  [0.         0.9419211 ]
#  [0.         1.13783416]
#  [1.         0.35692529]
#  [1.         0.75737268]
#  [3.         0.51354927]
#  [3.         0.44864655]
#  [1.         0.78672123]
#  [1.         0.76263665]
#  [3.         0.79027092]
#  [3.         0.22059691]
#  [2.         1.45187186]
#  [3.         0.84911106]
#  [1.         0.83483793]
#  [0.         0.82476883]
#  [0.         0.90361387]
#  [3.         0.54303324]
#  [2.         0.52265635]
#  [1.         0.77528051]
#  [3.         0.77381352]
#  [2.         0.3271121 ]
#  [1.         0.26749841]
#  [2.         0.22496858]
#  [2.         0.809203  ]
#  [0.         1.27668056]
#  [0.         0.30597269]
#  [3.         0.58589717]
#  [3.         0.92311741]
#  [3.         1.1907812 ]
#  [1.         1.09549178]
#  [0.         0.6767013 ]
#  [2.         0.78175818]
#  [3.         0.42689436]
#  [0.         0.72557566]
#  [3.         0.47100183]
#  [3.         0.55724858]
#  [2.         1.08859834]
#  [2.         0.32956368]
#  [2.         0.35648188]
#  [0.         0.90278451]
#  [2.         0.9102949 ]
#  [0.         0.51088226]
#  [0.         0.79553257]
#  [1.         0.64947871]
#  [1.         0.56334415]
#  [0.         0.84940673]
#  [1.         0.63956672]
#  [2.         1.4142355 ]]
#
# .....Updating Centroids
#  [[-1.63043905  3.09879034]
#  [-1.27208964  7.74944718]
#  [ 0.78627354  4.2491454 ]
#  [ 1.97918933  0.97920012]] =>
# [[-1.5772186   3.11456071]
#  [-1.27208964  7.74944718]
#  [ 0.83044547  4.27831711]
#  [ 1.97918933  0.97920012]]
#
#
# ====== Iteration 3 ======
# .....Assigning [0.669787   3.59540802] to 2th centroid by 0.702
# .....Assigning [-2.02396992  7.99569054] to 1th centroid by 0.791
# .....Assigning [1.43289271 4.37679234] to 2th centroid by 0.610
# .....Assigning [1.06923853 4.53068484] to 2th centroid by 0.347
# .....Assigning [1.71444449 5.02521524] to 2th centroid by 1.157
# .....Assigning [0.74387399 4.12240568] to 2th centroid by 0.178
# .....Assigning [-2.04363942  4.06392123] to 0th centroid by 1.058
# .....Assigning [-0.67860329  7.88799076] to 1th centroid by 0.609
# .....Assigning [-0.04749204  5.47425256] to 2th centroid by 1.484
# .....Assigning [-1.46976488  7.69183251] to 1th centroid by 0.206
# .....Assigning [-0.86417686  6.86528639] to 1th centroid by 0.974
# .....Assigning [-1.84838498  6.90859736] to 1th centroid by 1.019
# .....Assigning [-1.27182547  7.13460392] to 1th centroid by 0.615
# .....Assigning [-0.93428978  7.73253222] to 1th centroid by 0.338
# .....Assigning [-0.73415741  7.44484466] to 1th centroid by 0.618
# .....Assigning [3.18515794 0.08900822] to 3th centroid by 1.499
# .....Assigning [1.35139348 2.06383637] to 3th centroid by 1.253
# .....Assigning [-0.09701715  3.48456995] to 2th centroid by 1.221
# .....Assigning [-1.93150361  2.9369806 ] to 0th centroid by 0.396
# .....Assigning [2.73890793 0.15676817] to 3th centroid by 1.120
# .....Assigning [2.33812285 3.43116792] to 2th centroid by 1.729
# .....Assigning [-1.93673697  7.57276799] to 1th centroid by 0.688
# .....Assigning [-1.98885366  3.24143178] to 0th centroid by 0.431
# .....Assigning [ 2.33466499 -0.02408255] to 3th centroid by 1.064
# .....Assigning [0.43899014 4.53592883] to 2th centroid by 0.469
# .....Assigning [-1.58597553  2.51979529] to 0th centroid by 0.595
# .....Assigning [-0.3731388   3.80619114] to 2th centroid by 1.293
# .....Assigning [0.76752279 4.39759671] to 2th centroid by 0.135
# .....Assigning [2.94821884 2.03519717] to 3th centroid by 1.433
# .....Assigning [2.76253526 0.78970876] to 3th centroid by 0.806
# .....Assigning [1.65179125 0.68193176] to 3th centroid by 0.442
# .....Assigning [-0.8731169   6.87422542] to 1th centroid by 0.962
# .....Assigning [2.16172321 0.6565951 ] to 3th centroid by 0.371
# .....Assigning [2.06156753 1.96918596] to 3th centroid by 0.993
# .....Assigning [-1.15845639  3.47120626] to 0th centroid by 0.550
# .....Assigning [1.1641107  3.79132988] to 2th centroid by 0.590
# .....Assigning [-1.54707525  8.99317925] to 1th centroid by 1.274
# .....Assigning [1.81336135 1.6311307 ] to 3th centroid by 0.673
# .....Assigning [0.04968579 8.63737679] to 1th centroid by 1.592
# .....Assigning [-1.97375691  2.42201914] to 0th centroid by 0.798
# .....Assigning [1.06269622 5.17635143] to 2th centroid by 0.928
# .....Assigning [-1.42689992  3.29890112] to 0th centroid by 0.238
# .....Assigning [-1.63442682  6.50141812] to 1th centroid by 1.300
# .....Assigning [-2.07459735  3.58809203] to 0th centroid by 0.687
# .....Assigning [-1.94364473  2.82810154] to 0th centroid by 0.465
# .....Assigning [-1.98351709  8.3420778 ] to 1th centroid by 0.926
# .....Assigning [1.53278923 0.55035386] to 3th centroid by 0.619
# .....Assigning [-1.90841166  3.32374224] to 0th centroid by 0.392
# .....Assigning [0.67047877 4.04094275] to 2th centroid by 0.286
# .....Assigning [0.44359863 3.11530945] to 2th centroid by 1.226
# .....Assigning [0.22459286 4.77028154] to 2th centroid by 0.780
# .....Assigning [1.868336   0.93136287] to 3th centroid by 0.121
# .....Assigning [-1.18094952  2.79290301] to 0th centroid by 0.510
# .....Assigning [-1.78799614  4.0274405 ] to 0th centroid by 0.937
# .....Assigning [-0.85092246  2.26992336] to 0th centroid by 1.114
# .....Assigning [-1.26285145  7.39264147] to 1th centroid by 0.357
# .....Assigning [-0.78518144  8.32956251] to 1th centroid by 0.757
# .....Assigning [2.49272186 0.97505341] to 3th centroid by 0.514
# .....Assigning [2.26908736 1.32160756] to 3th centroid by 0.449
# .....Assigning [-0.5354379   8.02562558] to 1th centroid by 0.787
# .....Assigning [-1.46065212  7.01048924] to 1th centroid by 0.763
# .....Assigning [1.41281595 1.5303347 ] to 3th centroid by 0.790
# .....Assigning [2.13141478 1.13885728] to 3th centroid by 0.221
# .....Assigning [1.89593761 5.18540259] to 2th centroid by 1.399
# .....Assigning [1.29297652 1.47930168] to 3th centroid by 0.849
# .....Assigning [-0.58846002  8.22861825] to 1th centroid by 0.835
# .....Assigning [-2.31644846  2.6409315 ] to 0th centroid by 0.878
# .....Assigning [-1.28929999  2.26204536] to 0th centroid by 0.900
# .....Assigning [2.18023251 1.48364708] to 3th centroid by 0.543
# .....Assigning [1.24258802 4.50399192] to 2th centroid by 0.470
# .....Assigning [-1.86880148  8.24441673] to 1th centroid by 0.775
# .....Assigning [1.35617762 1.43815955] to 3th centroid by 0.774
# .....Assigning [0.91433877 4.55014643] to 2th centroid by 0.284
# .....Assigning [-1.52157528  7.84594751] to 1th centroid by 0.267
# .....Assigning [1.00372519 4.19147702] to 2th centroid by 0.194
# .....Assigning [1.4949318  3.85848832] to 2th centroid by 0.786
# .....Assigning [-0.40636864  3.46150906] to 0th centroid by 1.221
# .....Assigning [-1.68770604  3.3993561 ] to 0th centroid by 0.305
# .....Assigning [2.29667251 0.48677761] to 3th centroid by 0.586
# .....Assigning [1.07714851 1.17533301] to 3th centroid by 0.923
# .....Assigning [ 1.56737975 -0.1381059 ] to 3th centroid by 1.191
# .....Assigning [-1.69199357  8.76126877] to 1th centroid by 1.095
# .....Assigning [-1.34796111  3.7137138 ] to 0th centroid by 0.642
# .....Assigning [0.00793137 4.17614316] to 2th centroid by 0.829
# .....Assigning [1.67467427 0.68001896] to 3th centroid by 0.427
# .....Assigning [-0.95855283  2.82487621] to 0th centroid by 0.683
# .....Assigning [1.5108885 0.9288309] to 3th centroid by 0.471
# .....Assigning [1.80709613 0.44919077] to 3th centroid by 0.557
# .....Assigning [1.87271752 4.18069237] to 2th centroid by 1.047
# .....Assigning [1.01618041 4.48527047] to 2th centroid by 0.278
# .....Assigning [0.95936074 4.56078645] to 2th centroid by 0.310
# .....Assigning [-1.30104869  2.25824179] to 0th centroid by 0.900
# .....Assigning [0.3471383  3.45177657] to 2th centroid by 0.957
# .....Assigning [-1.12352716  3.16235936] to 0th centroid by 0.456
# .....Assigning [-2.42165857  3.18151728] to 0th centroid by 0.847
# .....Assigning [-1.91088578  7.86675906] to 1th centroid by 0.649
# .....Assigning [-1.73030157  7.42173015] to 1th centroid by 0.563
# .....Assigning [-1.56784898  3.94588789] to 0th centroid by 0.831
# .....Assigning [-0.69574048  8.02669661] to 1th centroid by 0.640
# .....Assigning [-0.55552381  4.69595848] to 2th centroid by 1.448
#
# .....Assigned clusters:
#  [[2.         0.70155255]
#  [1.         0.79117618]
#  [2.         0.61044251]
#  [2.         0.34743575]
#  [2.         1.15728608]
#  [2.         0.17833395]
#  [0.         1.05774939]
#  [1.         0.60944267]
#  [2.         1.48358885]
#  [1.         0.20590034]
#  [1.         0.97372129]
#  [1.         1.0193845 ]
#  [1.         0.61484332]
#  [1.         0.33822309]
#  [1.         0.61818588]
#  [3.         1.49893359]
#  [3.         1.25322122]
#  [2.         1.22074627]
#  [0.         0.39629858]
#  [3.         1.11962791]
#  [2.         1.72937932]
#  [1.         0.68772932]
#  [0.         0.43074318]
#  [3.         1.0643961 ]
#  [2.         0.46861612]
#  [0.         0.59482989]
#  [2.         1.292872  ]
#  [2.         0.13485876]
#  [3.         1.4332299 ]
#  [3.         0.8059391 ]
#  [3.         0.44221938]
#  [1.         0.96186921]
#  [3.         0.3706651 ]
#  [3.         0.99340733]
#  [0.         0.55005257]
#  [2.         0.59032961]
#  [1.         1.27376863]
#  [3.         0.67269042]
#  [1.         1.59232825]
#  [0.         0.79803287]
#  [2.         0.92758075]
#  [0.         0.2378594 ]
#  [1.         1.2995633 ]
#  [0.         0.68674415]
#  [0.         0.46510963]
#  [1.         0.9259266 ]
#  [3.         0.61901709]
#  [0.         0.39172153]
#  [2.         0.28624454]
#  [2.         1.22565791]
#  [2.         0.78043986]
#  [3.         0.12073468]
#  [0.         0.51038501]
#  [0.         0.93689737]
#  [0.         1.11396515]
#  [1.         0.35692529]
#  [1.         0.75737268]
#  [3.         0.51354927]
#  [3.         0.44864655]
#  [1.         0.78672123]
#  [1.         0.76263665]
#  [3.         0.79027092]
#  [3.         0.22059691]
#  [2.         1.39931325]
#  [3.         0.84911106]
#  [1.         0.83483793]
#  [0.         0.87794386]
#  [0.         0.89982196]
#  [3.         0.54303324]
#  [2.         0.46988361]
#  [1.         0.77528051]
#  [3.         0.77381352]
#  [2.         0.28448069]
#  [1.         0.26749841]
#  [2.         0.19382225]
#  [2.         0.78600146]
#  [0.         1.22117271]
#  [0.         0.30547649]
#  [3.         0.58589717]
#  [3.         0.92311741]
#  [3.         1.1907812 ]
#  [1.         1.09549178]
#  [0.         0.6415165 ]
#  [2.         0.8288359 ]
#  [3.         0.42689436]
#  [0.         0.68312842]
#  [3.         0.47100183]
#  [3.         0.55724858]
#  [2.         1.0468341 ]
#  [2.         0.27807762]
#  [2.         0.3104965 ]
#  [0.         0.89975103]
#  [2.         0.95747329]
#  [0.         0.4562024 ]
#  [0.         0.84709034]
#  [1.         0.64947871]
#  [1.         0.56334415]
#  [0.         0.83137998]
#  [1.         0.63956672]
#  [2.         1.44752726]]
#
# .....NOT Updating Centroids
#  [[-1.5772186   3.11456071]
#  [-1.27208964  7.74944718]
#  [ 0.83044547  4.27831711]
#  [ 1.97918933  0.97920012]] =>
# [[-1.5772186   3.11456071]
#  [-1.27208964  7.74944718]
#  [ 0.83044547  4.27831711]
#  [ 1.97918933  0.97920012]]
